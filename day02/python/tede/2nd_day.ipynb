# %% [markdown]
# You play several games and record the information from each game (your puzzle input). Each game is listed with its ID number (like the 11 in Game 11: ...) followed by a semicolon-separated list of subsets of cubes that were revealed from the bag (like 3 red, 5 green, 4 blue).
#
# For example, the record of a few games might look like this:
#
# Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
# Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
# Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
# Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
# Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green
# In game 1, three sets of cubes are revealed from the bag (and then put back again). The first set is 3 blue cubes and 4 red cubes; the second set is 1 red cube, 2 green cubes, and 6 blue cubes; the third set is only 2 green cubes.
#
# The Elf would first like to know which games would have been possible if the bag contained only 12 red cubes, 13 green cubes, and 14 blue cubes?
#
# In the example above, games 1, 2, and 5 would have been possible if the bag had been loaded with that configuration. However, game 3 would have been impossible because at one point the Elf showed you 20 red cubes at once; similarly, game 4 would also have been impossible because the Elf showed you 15 blue cubes at once. If you add up the IDs of the games that would have been possible, you get 8.
#
# Determine which games would have been possible if the bag had been loaded with only 12 red cubes, 13 green cubes, and 14 blue cubes. What is the sum of the IDs of those games?

# %%
import re

def extract_numbers_with_positions(input_string):
    # Using regular expression to find all numbers and their positions in the string
    matches = re.finditer(r'\d+', input_string)

    # Extracting numbers and their positions
    result = [(int(match.group()), match.start(), match.end()) for match in matches]

    return result

file_path = r'input.txt'
is_it_possible = True
sum = 0

with open(file_path, 'r') as f:
    for line in f:
        current_line = line.strip()

        split_line = current_line.split(':')
        ID = extract_numbers_with_positions(split_line[0])[0]
        #print(ID[0])
        number_stat = extract_numbers_with_positions(split_line[1])
        for Inumber in number_stat:
            if Inumber[0] > 12:
                color = split_line[1][Inumber[2] + 1]
                #print(f'{color}: {Inumber[0]}')
                if color == 'r':
                    is_it_possible = False
                    break
                    #print(f'r: {Inumber[0]}')
                    
                elif color == 'b' and Inumber[0] > 14:
                    is_it_possible = False
                    break
                    #print(f'b: {Inumber[0]}')
                    
                elif color == 'g'and Inumber[0] > 13:
                    is_it_possible = False
                    break
                    #print(f'g: {Inumber[0]}')



        if is_it_possible:
            sum += ID[0]
        #else:
        #    print(number_stat)

        is_it_possible = True

        

                
print(sum)
# Out:
# 1
# r: 15
# [(7, 1, 2), (5, 9, 10), (10, 16, 18), (7, 24, 25), (5, 32, 33), (4, 40, 41), (15, 49, 51), (4, 57, 58), (6, 66, 67), (7, 73, 74), (5, 81, 82), (8, 90, 91), (4, 98, 99), (5, 105, 106), (4, 112, 113), (3, 120, 121)]
# 2
# 3
# 4
# 5
# r: 17
# [(17, 1, 3), (5, 9, 10), (3, 17, 18), (8, 26, 27), (9, 35, 36), (10, 42, 44), (2, 51, 52), (9, 60, 61), (4, 68, 69)]
# 6
# r: 13
# [(5, 1, 2), (6, 9, 10), (3, 18, 19), (1, 25, 26), (8, 34, 35), (12, 42, 44), (2, 50, 51), (13, 58, 60), (6, 66, 67)]
# 7
# g: 14
# [(1, 1, 2), (1, 10, 11), (6, 18, 19), (1, 25, 26), (8, 32, 33), (3, 41, 42), (8, 48, 49), (2, 57, 58), (14, 65, 67), (4, 75, 76), (4, 83, 84), (4, 90, 91), (5, 99, 100), (7, 107, 108), (2, 116, 117), (1, 124, 125)]
# 8
# 9
# 10
# r: 14
# [(2, 1, 2), (2, 8, 9), (12, 16, 18), (8, 26, 27), (3, 35, 36), (5, 42, 43), (11, 50, 52), (6, 58, 59), (14, 67, 69), (1, 75, 76)]
# 11
# 12
# 13
# 14
# r: 17
# ...

# %%
import re

def extract_numbers_with_positions(input_string):
    # Using regular expression to find all numbers and their positions in the string
    matches = re.finditer(r'\d+', input_string)

    # Extracting numbers and their positions
    result = [(int(match.group()), match.start(), match.end()) for match in matches]

    return result

file_path = r'input.txt'
is_it_possible = True
sum = 0

with open(file_path, 'r') as f:
    for line in f:
        current_line = line.strip()
        red_max = 1
        blue_max = 1
        green_max = 1

        split_line = current_line.split(':')
        ID = extract_numbers_with_positions(split_line[0])[0]
        #print(split_line)
        number_stat = extract_numbers_with_positions(split_line[1])
        for Inumber in number_stat:
            color = split_line[1][Inumber[2] + 1]
            if color == 'r' and Inumber[0] > red_max:
                red_max = Inumber[0]
            elif color == 'b' and Inumber[0] > blue_max:
                blue_max = Inumber[0]
            elif color == 'g'and Inumber[0] > green_max:
                green_max = Inumber[0]

        #print(f'r: {red_max} b: {blue_max} g: {green_max}')
                
        power_of_set = red_max * blue_max * green_max


        if is_it_possible:
            sum += power_of_set


        

                
print(sum)
# Out:
# ['Game 1', ' 7 blue, 5 red; 10 red, 7 blue; 5 blue, 4 green, 15 red; 4 green, 6 red, 7 blue; 5 green, 8 blue, 4 red; 5 red, 4 blue, 3 green']
# r: 15 b: 8 g: 5
# ['Game 2', ' 8 green, 3 red; 7 blue, 6 red, 8 green; 7 blue, 3 green, 6 red; 8 green, 6 blue, 11 red; 6 blue, 3 green, 12 red']
# r: 12 b: 7 g: 8
# ['Game 3', ' 6 blue, 3 red, 7 green; 3 red, 3 green, 8 blue; 8 blue, 11 red, 4 green; 5 blue, 7 red, 6 green; 9 blue, 7 green, 1 red']
# r: 11 b: 9 g: 7
# ['Game 4', ' 3 red, 4 green; 5 red, 1 blue; 2 green; 3 green, 1 blue; 2 green, 1 blue, 1 red']
# r: 5 b: 1 g: 4
# ['Game 5', ' 17 red, 5 blue, 3 green; 8 green, 9 red, 10 blue; 2 green, 9 blue, 4 red']
# r: 17 b: 10 g: 8
# ['Game 6', ' 5 blue, 6 green, 3 red; 1 green, 8 blue, 12 red; 2 blue, 13 red, 6 green']
# r: 13 b: 8 g: 6
# ['Game 7', ' 1 green, 1 blue, 6 red; 1 red, 8 green; 3 red, 8 green, 2 blue; 14 green, 4 blue, 4 red; 4 green, 5 blue; 7 green, 2 blue, 1 red']
# r: 6 b: 5 g: 14
# ...
